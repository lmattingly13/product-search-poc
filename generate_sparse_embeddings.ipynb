# %%
! pip3 install --upgrade --quiet --user google-cloud-aiplatform google-cloud-storage

# %%
import pandas as pd

df = pd.read_json('monstro_TechProduct_11_09_2024.json')
df.head()
# Out:
#                                     _id  \
# 0  {'$oid': '659319d637bd9527a152e242'}
# 1  {'$oid': '6595a72037bd9527a18cae20'}
# 2  {'$oid': '6595a84637bd9527a18e25ae'}
# 3  {'$oid': '6596eeb137bd9527a135c636'}
# 4  {'$oid': '6596eee637bd9527a135ed91'}
#
#                                           attributes  \
# 0  [{'val': ['723548782084'], 'valSlug': ['072354...
# 1  [{'val': ['See at Nextlink'], 'valSlug': ['see...
# 2  [{'val': ['See at Horry Telephone Cooperative'...
# 3  [{'val': ['680580340736'], 'valSlug': ['068058...
# 4  [{'val': ['088381871747'], 'valSlug': ['008838...
#
#                                                 date  \
# 0  {'add': {'$date': '2024-01-01T20:00:20.311Z'},...
# 1  {'add': {'$date': '2024-01-03T18:27:42.252Z'},...
# 2  {'add': {'$date': '2024-01-03T18:32:36.252Z'},...
# 3  {'add': {'$date': '2024-01-04T17:45:19.277Z'},...
# 4  {'add': {'$date': '2024-01-04T17:46:11.994Z'},...
#
#                                               family    loc  \
# 0  [{'uuid': '870ca165-f6b0-4728-a251-d7b487a73f2...  en_US
# 1  [{'uuid': '2fe6192e-f84c-4639-a7c6-6acdfc4bf76...  en_US
# 2  [{'uuid': '61055781-e33e-4c05-bb9a-94bc81a1bd4...  en_US
# 3  [{'uuid': '12952c96-ee21-4436-b717-2e7528200f3...  en_US
# 4  [{'uuid': '7af6274d-4584-4782-8433-30d65e5fbe1...  en_US
#
#                                                  mfr  \
# 0  {'name': 'SharkNinja', 'id': 15013055, 'slug':...
# 1  {'name': 'Nextlink', 'id': 6244098, 'slug': 'n...
# 2  {'name': 'Horry Telephone Cooperative', 'id': ...
# 3  {'name': 'Hbada', 'slug': 'hbada', 'id': 15014...
# 4  {'name': 'Makita', 'slug': 'makita', 'id': 150...
#
#                                              product  \
# 0  {'name': 'Smart Screen Blender and Food Proces...
# 1  {'name': 'Nextlink', 'htopic': {'typePath': 'C...
# 2  {'name': 'Horry Telephone Cooperative', 'htopi...
# 3  {'name': 'Hbada Reclining Office Desk Chair | ...
# 4  {'name': 'Makita MP100DZ 12V max CXT® Lithium-...
#
#                                                slugs status  \
# 0  [{'name': 'smart-screen-blender-and-food-proce...   Live
# 1  [{'name': 'nextlink', 'type': 'product', 'addD...   Live
# 2  [{'name': 'horry-telephone-cooperative', 'type...   Live
# 3  [{'name': 'hbada-reclining-office-desk-chair-a...   Live
# 4  [{'name': 'makita-mp100dz-12v-max-cxt-lithium-...   Live
#
#                                    uuid  win images reviews  hasOffers3  \
# 0  21ddd0f9-d3a1-4b05-bce5-7c2c82300068  0.0    NaN     NaN         NaN
# 1  ad8fef74-3d27-4f8a-92ae-d5bb7f93f1c0  1.0    NaN     NaN         NaN
# 2  ba15c002-b2f6-464b-9d5e-280c344510d1  0.0    NaN     NaN         NaN
# 3  3ae3191c-0430-49f1-b1fc-ad1430243c20  0.0    NaN     NaN         NaN
# 4  c6315cd9-c055-44cb-9b34-cbbd41c35ffb  0.0    NaN     NaN         NaN
#
#    hasOffers4739  hasOffers5315  pRunId
# 0            NaN            NaN     NaN
# 1            NaN            NaN     NaN
# 2            NaN            NaN     NaN
# 3            NaN            NaN     NaN
# 4            NaN            NaN     NaN

# %%
df['product_name'] = df['product'].apply(lambda x: x['name'])

# %%
df.head()
# Out:
#                                     _id  \
# 0  {'$oid': '659319d637bd9527a152e242'}
# 1  {'$oid': '6595a72037bd9527a18cae20'}
# 2  {'$oid': '6595a84637bd9527a18e25ae'}
# 3  {'$oid': '6596eeb137bd9527a135c636'}
# 4  {'$oid': '6596eee637bd9527a135ed91'}
#
#                                           attributes  \
# 0  [{'val': ['723548782084'], 'valSlug': ['072354...
# 1  [{'val': ['See at Nextlink'], 'valSlug': ['see...
# 2  [{'val': ['See at Horry Telephone Cooperative'...
# 3  [{'val': ['680580340736'], 'valSlug': ['068058...
# 4  [{'val': ['088381871747'], 'valSlug': ['008838...
#
#                                                 date  \
# 0  {'add': {'$date': '2024-01-01T20:00:20.311Z'},...
# 1  {'add': {'$date': '2024-01-03T18:27:42.252Z'},...
# 2  {'add': {'$date': '2024-01-03T18:32:36.252Z'},...
# 3  {'add': {'$date': '2024-01-04T17:45:19.277Z'},...
# 4  {'add': {'$date': '2024-01-04T17:46:11.994Z'},...
#
#                                               family    loc  \
# 0  [{'uuid': '870ca165-f6b0-4728-a251-d7b487a73f2...  en_US
# 1  [{'uuid': '2fe6192e-f84c-4639-a7c6-6acdfc4bf76...  en_US
# 2  [{'uuid': '61055781-e33e-4c05-bb9a-94bc81a1bd4...  en_US
# 3  [{'uuid': '12952c96-ee21-4436-b717-2e7528200f3...  en_US
# 4  [{'uuid': '7af6274d-4584-4782-8433-30d65e5fbe1...  en_US
#
#                                                  mfr  \
# 0  {'name': 'SharkNinja', 'id': 15013055, 'slug':...
# 1  {'name': 'Nextlink', 'id': 6244098, 'slug': 'n...
# 2  {'name': 'Horry Telephone Cooperative', 'id': ...
# 3  {'name': 'Hbada', 'slug': 'hbada', 'id': 15014...
# 4  {'name': 'Makita', 'slug': 'makita', 'id': 150...
#
#                                              product  \
# 0  {'name': 'Smart Screen Blender and Food Proces...
# 1  {'name': 'Nextlink', 'htopic': {'typePath': 'C...
# 2  {'name': 'Horry Telephone Cooperative', 'htopi...
# 3  {'name': 'Hbada Reclining Office Desk Chair | ...
# 4  {'name': 'Makita MP100DZ 12V max CXT® Lithium-...
#
#                                                slugs status  \
# 0  [{'name': 'smart-screen-blender-and-food-proce...   Live
# 1  [{'name': 'nextlink', 'type': 'product', 'addD...   Live
# 2  [{'name': 'horry-telephone-cooperative', 'type...   Live
# 3  [{'name': 'hbada-reclining-office-desk-chair-a...   Live
# 4  [{'name': 'makita-mp100dz-12v-max-cxt-lithium-...   Live
#
#                                    uuid  win images reviews  hasOffers3  \
# 0  21ddd0f9-d3a1-4b05-bce5-7c2c82300068  0.0    NaN     NaN         NaN
# 1  ad8fef74-3d27-4f8a-92ae-d5bb7f93f1c0  1.0    NaN     NaN         NaN
# 2  ba15c002-b2f6-464b-9d5e-280c344510d1  0.0    NaN     NaN         NaN
# 3  3ae3191c-0430-49f1-b1fc-ad1430243c20  0.0    NaN     NaN         NaN
# 4  c6315cd9-c055-44cb-9b34-cbbd41c35ffb  0.0    NaN     NaN         NaN
#
#    hasOffers4739  hasOffers5315  pRunId  \
# 0            NaN            NaN     NaN
# 1            NaN            NaN     NaN
# 2            NaN            NaN     NaN
# 3            NaN            NaN     NaN
# 4            NaN            NaN     NaN
#
#                                         product_name
# 0  Smart Screen Blender and Food Processor with F...
# 1                                           Nextlink
# 2                        Horry Telephone Cooperative
# 3  Hbada Reclining Office Desk Chair | Adjustable...
# 4  Makita MP100DZ 12V max CXT® Lithium-Ion Cordle...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Sample Text Data
corpus = df.product_name.tolist()

# Initialize TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit and Transform
vectorizer.fit_transform(corpus)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 11497 stored elements and shape (1000, 3214)>

# %%
def get_sparse_embedding(text):
    # Transform Text into TF-IDF Sparse Vector
    tfidf_vector = vectorizer.transform([text])

    # Create Sparse Embedding for the New Text
    values = []
    dims = []
    for i, tfidf_value in enumerate(tfidf_vector.data):
        values.append(float(tfidf_value))
        dims.append(int(tfidf_vector.indices[i]))
    return {"values": values, "dimensions": dims}

# %%
text_test = "Tracfone - TCL 30 Z 32GB Prepaid with 1 Year of Service Bundle - Black"
get_sparse_embedding(text_test)
# Out:
# {'values': [0.340030379373264,
#   0.3208932379144901,
#   0.19684477991483407,
#   0.2802165447372101,
#   0.2802165447372101,
#   0.36791871020726175,
#   0.2466058551703064,
#   0.4201985791766876,
#   0.36791871020726175,
#   0.1470541986999019,
#   0.23639330352736787],
#  'dimensions': [175, 193, 586, 674, 2038, 2251, 2561, 2833, 2913, 3126, 3183]}

# %%
items = []
for i in range(len(df)):
    id = df.uuid[i]
    product_name = df.product_name[i]
    sparse_embedding = get_sparse_embedding(product_name)
    items.append({"id": id, "product_name": product_name, "sparse_embedding": sparse_embedding})
items[:5]
# Out:
# [{'id': '21ddd0f9-d3a1-4b05-bce5-7c2c82300068',
#   'product_name': 'Smart Screen Blender and Food Processor with FreshVac Technology, 1400-Peak-Watt Base, 9 Auto-iQ Programs & Touchscreen Display for Ninja (CT672V) (Renewed)',
#   'sparse_embedding': {'values': [0.25844626203877996,
#     0.10838258514252433,
#     0.1797467941006616,
#     0.24392344602592173,
#     0.22562686168301443,
#     0.25844626203877996,
#     0.1778102321348284,
#     0.23361934408257903,
#     0.10731332151763603,
#     0.25844626203877996,
#     0.24392344602592173,
#     0.23361934408257903,
#     0.21357520967111993,
#     0.22562686168301443,
#     0.25844626203877996,
#     0.23361934408257903,
#     0.19426961011351987,
#     0.15696715743003792,
#     0.21357520967111993,
#     0.21357520967111993,
#     0.23361934408257903,
#     0.08536432219676277],
#    'dimensions': [65,
#     443,
#     489,
#     537,
#     594,
#     908,
#     1013,
#     1254,
#     1258,
#     1278,
#     1592,
#     1990,
#     2147,
#     2265,
#     2268,
#     2406,
#     2527,
#     2642,
#     2841,
#     2903,
#     3082,
#     3126]}},
#  {'id': 'ad8fef74-3d27-4f8a-92ae-d5bb7f93f1c0',
#   'product_name': 'Nextlink',
#   'sparse_embedding': {'values': [1.0], 'dimensions': [1981]}},
#  {'id': 'ba15c002-b2f6-464b-9d5e-280c344510d1',
#   'product_name': 'Horry Telephone Cooperative',
#   'sparse_embedding': {'values': [0.5773502691896258,
#     0.5773502691896258,
#     0.5773502691896258],
#    'dimensions': [875, 1488, 2843]}},
#  {'id': '3ae3191c-0430-49f1-b1fc-ad1430243c20',
#   'product_name': 'Hbada Reclining Office Desk Chair | Adjustable High Back Ergonomic Mesh Computer Recliner | Home Office Chairs with Footrest and Lumbar Support, Black',
#   'sparse_embedding': {'values': [0.1913226610478364,
#     0.10673848878676656,
#     0.2056251749812537,
#     0.11253417042102837,
#     0.21577297011172486,
#     0.2402232791756133,
#     0.18849920739208112,
#     0.21033540667658218,
#     0.2300754840451422,
#     0.2545257931090307,
#     0.2545257931090307,
#     0.2056251749812537,
#     0.16019696541555353,
#     0.2545257931090307,
#     0.2300754840451422,
#     0.402940912356615,
#     0.2402232791756133,
#     0.2545257931090307,
#     0.2300754840451422,
#     0.08406939856257493],
#    'dimensions': [389,
#     443,
#     505,
#     586,
#     756,
#     757,
#     850,
#     984,
#     1142,
#     1257,
#     1429,
#     1463,
#     1478,
#     1768,
#     1844,
#     2041,
#     2374,
#     2375,
#     2780,
#     3126]}},
#  {'id': 'c6315cd9-c055-44cb-9b34-cbbd41c35ffb',
#   'product_name': 'Makita MP100DZ 12V max CXT® Lithium-Ion Cordless Inflator, Bare Tool Only',
#   'sparse_embedding': {'values': [0.28220771385512167,
#     0.31418607435318746,
#     0.23695713458490122,
#     0.3328922160790987,
#     0.30091385558103284,
#     0.30091385558103284,
#     0.28220771385512167,
#     0.3328922160790987,
#     0.16952997938706046,
#     0.3328922160790987,
#     0.2431176083355211,
#     0.29061912290826925],
#    'dimensions': [57,
#     532,
#     880,
#     928,
#     1556,
#     1582,
#     1743,
#     1807,
#     1828,
#     1924,
#     2051,
#     2896]}}]

# %%
input_file_path = 'sparse_embedding_products_11_09_2024.json'
with open(input_file_path, 'r') as input_file:
    raw_records = input_file.readlines()  # Read lines from the file

# Loop through the records and check for valid JSON
for line_number, record in enumerate(raw_records, start=1):
    record = record.strip()  # Clean up whitespace

    # Skip empty lines
    if not record:
        continue

    # Replace single quotes with double quotes for JSON compatibility
    record = record.replace("'", '"')

    # Check if the record is a valid JSON object
    try:
        json.loads(record)  # Attempt to load the record as JSON
    except json.JSONDecodeError as e:
        # If there's an error, attempt to extract the product name
        product_name_match = re.search(r'"product_name":\s*"([^"]*?)"', record)
        product_name = product_name_match.group(1) if product_name_match else 'N/A'
        
        # Print the line number and product name
        print(f"Line {line_number}: Invalid JSON - Product Name: {product_name}")

print("Finished checking for valid JSON lines.")
# Out:
# Line 9: Invalid JSON - Product Name:
# Line 11: Invalid JSON - Product Name:
# Line 22: Invalid JSON - Product Name: Under Armour Women
# Line 28: Invalid JSON - Product Name: Wsedper Color Changing Shorts, Men
# Line 34: Invalid JSON - Product Name:
# Line 43: Invalid JSON - Product Name: Salomon Women
# Line 56: Invalid JSON - Product Name: Amazfit Bip S Fitness Smartwatch, 40 Day Battery Life, 10 Sports Modes, Heart Rate, 1.28
# Line 70: Invalid JSON - Product Name: Cozy Earth Women
# Line 90: Invalid JSON - Product Name: BEAUTYPEAK 64
# Line 124: Invalid JSON - Product Name: PASELEC Electric Bikes for Adult, 27.5
# Line 170: Invalid JSON - Product Name: Better Homes & Gardens Blue Medallion Outdoor 24
# Line 177: Invalid JSON - Product Name: Seizeen 75 Gallon Resin Deck Box on Wheels, Patio Large Storage Cabinet, Outdoor Waterproof Storage Chest, Storage Container for Outside Furniture Cushions, Garden Tools, Kids
# Line 184: Invalid JSON - Product Name: iDOO Hydroponics Growing System Kit 12Pods, Fathers Day Dad Gifts, Herb Garden Indoor with LED Grow Light, Gifts for Mom, Built-in Fan, Auto-Timer, Adjustable Height Up to 11.3
# Line 194: Invalid JSON - Product Name:
# Line 197: Invalid JSON - Product Name: PASELEC Electric Bike for Adults, Peak 750W BAFANG Motor 48V 13Ah Battery Shimano 8-Speed Gears, 28MPH Full Suspension Ebike, 27.5
# Line 199: Invalid JSON - Product Name: Inov-8 Women
# Line 219: Invalid JSON - Product Name: Gotrax Electric Balance Bike for Kid, 14
# Line 220: Invalid JSON - Product Name: 16
# Line 228: Invalid JSON - Product Name: Cloverlane Hybrid Luxury Firm Mattress 15
# Line 254: Invalid JSON - Product Name: Goplus 10
# Line 263: Invalid JSON - Product Name: Fire Pits for Outside, 32
# Line 272: Invalid JSON - Product Name: Citizen Men
# Line 287: Invalid JSON - Product Name: LUBA 2 AWD 1000H Robot Lawn Mower, Perimeter Wire Free Vision Robotic Lawnmower for 0.25 Acre Lawn, Cut Height 2.2
# Line 294: Invalid JSON - Product Name: Lenovo ThinkPad L390 Yoga 2-in-1, 13.3
# Line 299: Invalid JSON - Product Name: Lenovo ThinkPad X1 Carbon Gen 10 Laptop, 14
# Line 300: Invalid JSON - Product Name: lenovo IdeaPad Slim 7 Pro 14IHU5 14
# Line 302: Invalid JSON - Product Name: Lenovo ThinkVision S27i-10 1080p 27
# Line 304: Invalid JSON - Product Name: Inov-8 Men
# Line 313: Invalid JSON - Product Name: Lenovo ThinkBook Plus Gen 4 Laptop, 13.312
# Line 315: Invalid JSON - Product Name:
# Line 322: Invalid JSON - Product Name: BEAUTYPEAK 36
# Line 323: Invalid JSON - Product Name: Lenovo ThinkPad X1 Fold Gen 1 Laptop, 13.3
# Line 381: Invalid JSON - Product Name: Gardein Ultimate Plant-Based Chick
# Line 384: Invalid JSON - Product Name: PAWZ Road Tall Cat Tree Cactus Floor to Ceiling Cat Tower 95-108
# Line 386: Invalid JSON - Product Name: Segway Ninebot E2 Electric KickScooter- 250W Brushless Motor, Up to 15.5 Miles Range & 12.4 MPH, 8.1
# Line 388: Invalid JSON - Product Name: Segway SuperScooter GT2P Electric Scooter, Up to 55.9 Miles and 43.5 MPH, E Scooter Adults for Commuting w/t 11
# Line 393: Invalid JSON - Product Name: ONYX BOOX Note Air 3 C 10.3
# Line 398: Invalid JSON - Product Name: Pre-Owned Apple iPad Mini 5 7.9
# Line 407: Invalid JSON - Product Name: Kindle_ Paper white 16 GB E-Reader 6
# Line 415: Invalid JSON - Product Name:
# Line 421: Invalid JSON - Product Name:
# Line 425: Invalid JSON - Product Name: DOOGEE V Max 5G Rugged Phone 6.58
# Line 426: Invalid JSON - Product Name: Sony Interactive Entertainment - DualSense\xa0Wireless Controller – 30th Anniversary Limited Edition - Gray
# Line 448: Invalid JSON - Product Name: Onn. 4K UHD LED Roku Smart TV 98
# Line 462: Invalid JSON - Product Name: Under Armour Men
# Line 471: Invalid JSON - Product Name: onn. 10.1
# Line 475: Invalid JSON - Product Name: BEAUTYPEAK 64
# Line 476: Invalid JSON - Product Name: GIRUNS Men
# Line 478: Invalid JSON - Product Name: SHEWIN Women
# Line 482: Invalid JSON - Product Name: Lenovo IdeaPad 1i 15.6
# Line 485: Invalid JSON - Product Name: JW PEI Women
# Line 515: Invalid JSON - Product Name: Samsung - Galaxy Tab S7 FE - 12.4
# Line 524: Invalid JSON - Product Name: Travelhouse Hardshell Carry on Luggage 20
# Line 527: Invalid JSON - Product Name: Christmas Wrapping Paper, Holiday Wrapping Paper, 9 Pack Brown Kraft Paper, Snow, Christmas Tree, Snowman, Lantern and Color Elk (9-Sheets, 30
# Line 531: Invalid JSON - Product Name: UPERFECT 18 UMax - Portable monitor 18.5
# Line 532: Invalid JSON - Product Name: Portable Monitor Zero Frame, 15.6
# Line 533: Invalid JSON - Product Name: ZVOX AccuVoice 24
# Line 537: Invalid JSON - Product Name: JVC 40
# Line 538: Invalid JSON - Product Name: ROVE R2-4K DUAL Dash Cam Front and Rear, STARVIS 2 Sensor, FREE 128GB Card Included, 5G WiFi - up to 20MB/s Fastest Download Speed with App, 4K 2160P/FHD Dash Camera for Cars, 3
# Line 548: Invalid JSON - Product Name: BOOX Note Air3 C 10.3
# Line 550: Invalid JSON - Product Name: SAMSUNG 55
# Line 561: Invalid JSON - Product Name: HP Newest All-in-One Desktop Computer, 21.5
# Line 569: Invalid JSON - Product Name: Lenovo Legion 5 15.6
# Line 575: Invalid JSON - Product Name: Lenovo 27
# Line 576: Invalid JSON - Product Name: Lenovo 27
# Line 577: Invalid JSON - Product Name: Lenovo 27
# Line 582: Invalid JSON - Product Name: BYTECH USB Type-C Cable (2-Pack, 6
# Line 583: Invalid JSON - Product Name: BYTECH Micro 90-Degree Tip Cable (3.5
# Line 590: Invalid JSON - Product Name: BYTECH Micro 90-Degree Tip Cable (3.5
# Line 596: Invalid JSON - Product Name: Hikvision DS-D2049LU-Y 49
# Line 657: Invalid JSON - Product Name: MSI Bravo 15 15.6
# Line 660: Invalid JSON - Product Name:
# Line 747: Invalid JSON - Product Name: le mini macaron Maxi J
# Line 748: Invalid JSON - Product Name: Greenworks 60V 25
# Line 750: Invalid JSON - Product Name:
# Line 751: Invalid JSON - Product Name:
# Line 752: Invalid JSON - Product Name:
# Line 753: Invalid JSON - Product Name:
# Line 780: Invalid JSON - Product Name: Reebok Lite Plus 3 Women
# Line 782: Invalid JSON - Product Name: Inov-8 Women
# Line 787: Invalid JSON - Product Name:
# Line 789: Invalid JSON - Product Name:
# Line 794: Invalid JSON - Product Name: FLIR Clamp Meter, Flex, 3000A Ac TRMS Cat IV 18
# Line 800: Invalid JSON - Product Name: Kids Tablet Bundle: Includes Amazon Fire HD 10 Kids tablet, 10.1
# Line 801: Invalid JSON - Product Name: ASUS TUF Gaming A17 (2023) Gaming Laptop, 17.3
# Line 813: Invalid JSON - Product Name:
# Line 814: Invalid JSON - Product Name:
# Line 815: Invalid JSON - Product Name:
# Line 819: Invalid JSON - Product Name: LENOVO Yoga AIO 9i 2023 Latest Premier AIO Desktop, 31.5
# Line 833: Invalid JSON - Product Name:
# Line 834: Invalid JSON - Product Name: Certified Refurbished Fire HD 10 Tablet with Alexa Hands-Free, 10.1
# Line 835: Invalid JSON - Product Name: Heating Pad - Electric Heating Pads - Hot Heated Pad for Back Pain Muscle Pain Relieve - Dry & Moist Heat Option - Auto Shut Off Function (Blue, 12
# Line 836: Invalid JSON - Product Name: SAMSUNG Galaxy Tab S6 Lite (2024)+ $100 Amazon Gift Card 10.4
# Line 840: Invalid JSON - Product Name: LG 21HQ613D-B 21
# Line 859: Invalid JSON - Product Name: Lenovo 14
# Line 875: Invalid JSON - Product Name:
# Line 885: Invalid JSON - Product Name: Samsung Crystal CU7000 50
# Line 901: Invalid JSON - Product Name: Samsung M80C 32
# Line 904: Invalid JSON - Product Name: MSI 21.5
# Line 909: Invalid JSON - Product Name: Apple 3-Year AppleCare+ for Schools 13
# Line 915: Invalid JSON - Product Name: Dell 15.6
# Line 922: Invalid JSON - Product Name: MAGIC FLAME 5PC Grill Set, Stainless Steel Grill Tools Ideal Gift Set for Men, 18
# Line 925: Invalid JSON - Product Name: Swift Trinocular Cordless LED Microscope with 8
# Line 928: Invalid JSON - Product Name: Swift Trinocular Corded LED Microscope with Plan Lenses and 10
# Line 930: Invalid JSON - Product Name: Swift Trinocular Corded LED Microscope with Semi-Plan Lenses and 10
# Line 931: Invalid JSON - Product Name: Swift Trinocular Corded LED Microscope with Achromatic Super Contrast Lenses and 10
# Line 933: Invalid JSON - Product Name: TAQY New Block Game Console with 26 Game Macaron Colors Retro Game Machine Pocket Game Machine Brick Game/Racing/Tank Battle Puzzle Toy Electronic Nostalgic Handheld Device Children
# Line 939: Invalid JSON - Product Name: Bluestar Ultrasuede Cleaning Cloth (Jaguar, Small, 8 x 8
# Line 940: Invalid JSON - Product Name: Bluestar Ultrasuede Cleaning Cloth (Jaguar, Large, 12 x 12
# Line 953: Invalid JSON - Product Name:
# Line 959: Invalid JSON - Product Name:
# Line 961: Invalid JSON - Product Name: MSI 17
# Line 973: Invalid JSON - Product Name:
# Line 974: Invalid JSON - Product Name:
# Line 976: Invalid JSON - Product Name: HP 11.6
# Line 977: Invalid JSON - Product Name: HP 11.6
# Line 978: Invalid JSON - Product Name: HP 11.6
# Line 979: Invalid JSON - Product Name: HP 11.6
# Line 980: Invalid JSON - Product Name: HP 11.6
# Line 981: Invalid JSON - Product Name: HP 11.6
# Line 982: Invalid JSON - Product Name: HP 11.6
# Line 993: Invalid JSON - Product Name: Lenovo V15 Gen 3 Business Laptop, 15.6
# Line 995: Invalid JSON - Product Name: Dell Inspiron 15 3000 [Windows 11 Pro] Business Laptop Computer, 15.6
# Finished checking for valid JSON lines.

# %%
with open("sparse_embedding_products_11_09_2024.json", "r") as input_file:
    raw_records = input_file.readlines()

# %%
with open("sparse_embedding_products_11_09_2024.json", "w") as f:
    for item in items:
        f.write(f"{item}\n")

# %% [markdown]
# Create a spare embedding index in vector search

# %%
from google.cloud import aiplatform
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/lmattingly/Downloads/rv-hermes-nonprod-3a8067e91511.json"

# Replace with your project ID, region, and bucket name
project_id = "rv-hermes-nonprod"
region = "us-central1"

aiplatform.init(project=project_id, location=region)

# %%
BUCKET_URI = f"gs://commerce-product-search-data/sparse_embedding_products_11_09_2024.json"

UID= "sparse_embedding_products_11_09_2024"

# create Index (this should finish less than one minute)
my_sparse_index = aiplatform.MatchingEngineIndex.create_tree_ah_index(
    display_name=f"commerce-product-search-index-poc_{UID}",
    contents_delta_uri=BUCKET_URI,
    dimensions=768,
    approximate_neighbors_count=10,
)
# Out:
# Creating MatchingEngineIndex
# Create MatchingEngineIndex backing LRO: projects/3048625469/locations/us-central1/indexes/3038553159917109248/operations/5570926797454835712
# MatchingEngineIndex created. Resource name: projects/3048625469/locations/us-central1/indexes/3038553159917109248
# To use this MatchingEngineIndex in another session:
# index = aiplatform.MatchingEngineIndex('projects/3048625469/locations/us-central1/indexes/3038553159917109248')

# %%
ENDPOINT = f"commerce-product-index-endpoint-poc_{UID}"

my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint.create(
    display_name=ENDPOINT, public_endpoint_enabled=True
)
# Out:
# Creating MatchingEngineIndexEndpoint
# Create MatchingEngineIndexEndpoint backing LRO: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392/operations/4085864820329414656
# MatchingEngineIndexEndpoint created. Resource name: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392
# To use this MatchingEngineIndexEndpoint in another session:
# index_endpoint = aiplatform.MatchingEngineIndexEndpoint('projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392')

# %%
DEPLOYED_TOKEN_INDEX_ID = f"commerce_product_search_deployed_{UID}"
my_index_endpoint.deploy_index(
    index=my_sparse_index, deployed_index_id=DEPLOYED_TOKEN_INDEX_ID
)
# Out:
# Deploying index MatchingEngineIndexEndpoint index_endpoint: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392
# Deploy index MatchingEngineIndexEndpoint index_endpoint backing LRO: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392/operations/1421985640739766272
# MatchingEngineIndexEndpoint index_endpoint Deployed index. Resource name: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392
# <google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint.MatchingEngineIndexEndpoint object at 0x14f906650>
# resource name: projects/3048625469/locations/us-central1/indexEndpoints/3582310038363963392

# %%
#Trying to update the index as it doesnt show a sparse count
sparse_embedding_index = aiplatform.MatchingEngineIndex(index_name="projects/rv-hermes-nonprod/locations/us-central1/indexes/6569938217728999424")

# %%
# the UPDATE below is the only API that has error handling for uploading contents, when you run the create you could send it complete garbage and it doesnt care
sparse_embedding_index.update_embeddings(contents_delta_uri="gs://commerce-product-search-data/sparse_vector_search_index")
# Out:
# Updating MatchingEngineIndex index: projects/3048625469/locations/us-central1/indexes/6569938217728999424
# Update MatchingEngineIndex index backing LRO: projects/3048625469/locations/us-central1/indexes/6569938217728999424/operations/1265485553688641536
# ---------------------------------------------------------------------------
# FailedPrecondition                        Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 sparse_embedding_index.update_embeddings(contents_delta_uri="gs://commerce-product-search-data/sparse_vector_search_index")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/cloud/aiplatform/matching_engine/matching_engine_index.py:392, in MatchingEngineIndex.update_embeddings(self, contents_delta_uri, is_complete_overwrite, request_metadata, update_request_timeout)
#     381 update_lro = self.api_client.update_index(
#     382     index=gapic_index,
#     383     update_mask=update_mask,
#     384     metadata=request_metadata,
#     385     timeout=update_request_timeout,
#     386 )
#     388 _LOGGER.log_action_started_against_resource_with_lro(
#     389     "Update", "index", self.__class__, update_lro
#     390 )
# --> 392 self._gca_resource = update_lro.result(timeout=None)
#     394 _LOGGER.log_action_completed_against_resource("index", "Updated", self)
#     396 return self
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# FailedPrecondition: 400 There are invalid records under files [gs://commerce-product-search-data/sparse_vector_search_index/sparse_embedding_products_11_09_2024.json]. Please check the details in the metadata of operation: projects/3048625469/locations/us-central1/indexes/6569938217728999424/operations/1265485553688641536. 9: There are invalid records under files [gs://commerce-product-search-data/sparse_vector_search_index/sparse_embedding_products_11_09_2024.json]. Please check the details in the metadata of operation: projects/3048625469/locations/us-central1/indexes/6569938217728999424/operations/1265485553688641536.

# %%
from google.cloud.aiplatform.matching_engine.matching_engine_index_endpoint import (
    HybridQuery,
)

# create HybridQuery
query_text = "Tvs"
query_emb = get_sparse_embedding(query_text)
query = HybridQuery(
    sparse_embedding_dimensions=query_emb["dimensions"],
    sparse_embedding_values=query_emb["values"],
)

# %%
ENDPOINT_ID = "3582310038363963392"
my_index_endpoint = aiplatform.MatchingEngineIndexEndpoint(
    index_endpoint_name=f"{ENDPOINT_ID}"
)

# %%
DEPLOYED_TOKEN_INDEX_ID = 'commerce_product_search_deployed_sparse_embedding_products_11_09_2024'
# build a query request
response = my_index_endpoint.find_neighbors(
    deployed_index_id=DEPLOYED_TOKEN_INDEX_ID,
    queries=[query],
    num_neighbors=5,
)

# print results
for idx, neighbor in enumerate(response[0]):
    print(f"Neighbor {idx+1}, nei")
    title = df.title[int(neighbor.id)]
    print(f"{title:<40}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 10
#       3 response = my_index_endpoint.find_neighbors(
#       4     deployed_index_id=DEPLOYED_TOKEN_INDEX_ID,
#       5     queries=[query],
#       6     num_neighbors=5,
#       7 )
#       9 # print results
# ---> 10 for idx, neighbor in enumerate(response[0]):
#      11     print(f"Neighbor {idx+1}, nei")
#      12     title = df.title[int(neighbor.id)]
#
# IndexError: list index out of range

# %%
index = aiplatform.MatchingEngineIndex('projects/3048625469/locations/us-central1/indexes/8985556467859849216')
